# %% [markdown]
# <a href="https://colab.research.google.com/github/VittoriaDespo/Pipeline-Etl-Santander-Bootcamp/blob/master/ETL_Aluguel_2023.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ETL Pipelines | Alugueis Rio de Janeiro

# %% [markdown]
# **Contexto**: nesse projeto de ETL foi analisado o dataset *aluguel.csv* com o objetivo de calcular o valor bruto, o valor por m2, e o valor bruto por m2 dos alugueis.
#
# **Base de dados** : O database contém as seguintes informações:
#
# *   Tipo de imóvel
# *   Bairro onde está localizado o imóvel
# *   Quantidade de quartos
# *   Numero de vagas
# *   Quantidade de suites
# *   Area do imóvel
# *   Valor do imóvel
# *   Valor do condominio
# *   Valor do IPTU

# %% [markdown]
# # Extract

# %% [markdown]
# Extraindo base de dados a partir de uma arquivo csv

# %%
import pandas as pd

# %%
dados = pd.read_csv('aluguel.csv', sep=';')

# %%
dados.head()
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
#
#     Valor  Condominio    IPTU
# 0  1700.0       500.0    60.0
# 1  7000.0         NaN     NaN
# 2  5200.0      4020.0  1111.0
# 3   800.0       390.0    20.0
# 4   800.0       230.0     NaN

# %% [markdown]
# #Transform

# %% [markdown]
# ### Data Cleansing

# %% [markdown]
# Analisando a base de dados

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32960 entries, 0 to 32959
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Tipo        32960 non-null  object
#  1   Bairro      32960 non-null  object
#  2   Quartos     32960 non-null  int64
#  3   Vagas       32960 non-null  int64
#  4   Suites      32960 non-null  int64
#  5   Area        32960 non-null  int64
#  6   Valor       32943 non-null  float64
#  7   Condominio  28867 non-null  float64
#  8   IPTU        22723 non-null  float64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 2.3+ MB

# %% [markdown]
# Verificando a quantidade de valores nulos
# que existem na coluna "Valor"

# %%
dados[dados['Valor'].isnull()].shape
# Out:
# (17, 9)

# %% [markdown]
# Descartando as linhas que contêm valor nulo(NaN) na coluna "Valor"

# %%
dados.dropna(subset = ['Valor'], inplace = True)

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32943 entries, 0 to 32959
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Tipo        32943 non-null  object
#  1   Bairro      32943 non-null  object
#  2   Quartos     32943 non-null  int64
#  3   Vagas       32943 non-null  int64
#  4   Suites      32943 non-null  int64
#  5   Area        32943 non-null  int64
#  6   Valor       32943 non-null  float64
#  7   Condominio  28854 non-null  float64
#  8   IPTU        22716 non-null  float64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 2.5+ MB

# %% [markdown]
# Analisando a coluna "Tipo"

# %%
dados.drop_duplicates(subset=['Tipo'])
# Out:
#                               Tipo           Bairro  Quartos  Vagas  Suites  \
# 0                        Quitinete       Copacabana        1      0       0
# 1                             Casa  Jardim Botânico        2      0       1
# 2          Conjunto Comercial/Sala  Barra da Tijuca        0      4       0
# 3                      Apartamento           Centro        1      0       0
# 7               Casa de Condomínio  Barra da Tijuca        5      4       5
# 16                  Prédio Inteiro         Botafogo        0      0       0
# 17                            Flat         Botafogo        3      1       1
# 29                      Loja/Salão     Campo Grande        0      1       0
# 80         Galpão/Depósito/Armazém    Vargem Grande        0      6       0
# 83                  Casa Comercial         Botafogo        0      0       0
# 117                   Casa de Vila          Piedade        2      1       0
# 159                 Terreno Padrão  Barra da Tijuca        0      0       0
# 207                    Box/Garagem           Tijuca        0      0       0
# 347                           Loft  Barra da Tijuca        1      1       1
# 589    Loja Shopping/ Ct Comercial  Barra da Tijuca        0      2       0
# 2157                       Chácara        Guaratiba        3      0       0
# 3354         Loteamento/Condomínio      São Conrado        0      0       0
# 4379                         Sítio      Jacarepaguá        8      0       7
# 4721                 Pousada/Chalé  Barra da Tijuca       23      0      23
# 6983                        Studio           Gamboa        0      0       0
# 9687                         Hotel       Copacabana       24      0      24
# 23614                    Indústria    Vigário Geral        0      0       0
#
#        Area     Valor  Condominio    IPTU
# 0        40    1700.0       500.0    60.0
# 1       100    7000.0         NaN     NaN
# 2       150    5200.0      4020.0  1111.0
# 3        15     800.0       390.0    20.0
# 7       750   22000.0         NaN     NaN
# 16      536   28000.0         NaN  3563.0
# 17       80    3800.0      1040.0     NaN
# 29       35    1300.0       950.0     NaN
# 80     2236   40000.0         NaN     NaN
# 83      140    7000.0         NaN   137.0
# 117      70    1300.0         NaN     NaN
# 159    1110  140000.0         NaN     NaN
# 207       0     380.0         NaN     NaN
# 347      78    2700.0      1370.0   188.0
# 589      88    2500.0      4500.0  1544.0
# 2157      0    4900.0         NaN     NaN
# 3354   1000   20000.0         NaN     NaN
# 4379   1200   15000.0         NaN  3700.0
# 4721    862    1480.0       295.0     NaN
# 6983    110    1500.0         NaN    50.0
# 9687   1100   38000.0         NaN  7504.0
# 23614    22  120000.0         NaN     NaN

# %% [markdown]
# Verificando a quantidade de valores nulos que existem na coluna "Condominio"

# %%
dados[dados['Condominio'].isnull()].shape
# Out:
# (4089, 9)

# %% [markdown]
# Selecionando as *Casas de Condomínio*	com o valor de condomínio nulo

# %%
select_casa_condominio = (dados['Tipo'] == 'Casa de Condomínio') & (dados['Condominio'].isnull())
dados[select_casa_condominio]
# Out:
#                      Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 7      Casa de Condomínio  Barra da Tijuca        5      4       5   750
# 8      Casa de Condomínio            Ramos        2      2       0    65
# 18     Casa de Condomínio          Taquara        3      1       1   115
# 916    Casa de Condomínio              Joá        6      4       6   550
# 1625   Casa de Condomínio  Barra da Tijuca        5      3       5   700
# ...                   ...              ...      ...    ...     ...   ...
# 31363  Casa de Condomínio        Guaratiba        2      0       0    70
# 31375  Casa de Condomínio        Guaratiba        2      1       2    75
# 31453  Casa de Condomínio  Barra da Tijuca        5      0       5   850
# 31766  Casa de Condomínio  Barra da Tijuca        5      6       5  1300
# 32190  Casa de Condomínio    São Cristóvão        2      0       2   120
#
#          Valor  Condominio   IPTU
# 7      22000.0         NaN    NaN
# 8       1000.0         NaN    NaN
# 18      2000.0         NaN    NaN
# 916    25000.0         NaN  672.0
# 1625   25000.0         NaN    NaN
# ...        ...         ...    ...
# 31363   1000.0         NaN    NaN
# 31375   1700.0         NaN    NaN
# 31453  28000.0         NaN    NaN
# 31766  34009.0         NaN    NaN
# 32190   2000.0         NaN    NaN
#
# [95 rows x 9 columns]

# %% [markdown]
# Descartando as *Casas de Condomínio*	com o valor de condomínio nulo

# %%
dados = dados[~select_casa_condominio]
dados
# Out:
#                           Tipo                Bairro  Quartos  Vagas  Suites  \
# 0                    Quitinete            Copacabana        1      0       0
# 1                         Casa       Jardim Botânico        2      0       1
# 2      Conjunto Comercial/Sala       Barra da Tijuca        0      4       0
# 3                  Apartamento                Centro        1      0       0
# 4                  Apartamento          Higienópolis        1      0       0
# ...                        ...                   ...      ...    ...     ...
# 32955                Quitinete                Centro        0      0       0
# 32956              Apartamento           Jacarepaguá        3      1       2
# 32957              Apartamento  São Francisco Xavier        2      1       0
# 32958              Apartamento                Leblon        2      0       0
# 32959  Conjunto Comercial/Sala                Centro        0      0       0
#
#        Area   Valor  Condominio    IPTU
# 0        40  1700.0       500.0    60.0
# 1       100  7000.0         NaN     NaN
# 2       150  5200.0      4020.0  1111.0
# 3        15   800.0       390.0    20.0
# 4        48   800.0       230.0     NaN
# ...     ...     ...         ...     ...
# 32955    27   800.0       350.0    25.0
# 32956    78  1800.0       800.0    40.0
# 32957    48  1400.0       509.0    37.0
# 32958    70  3000.0       760.0     NaN
# 32959   250  6500.0      4206.0  1109.0
#
# [32848 rows x 9 columns]

# %%
dados[dados['Tipo']=='Casa de Condomínio']
# Out:
#                      Tipo                    Bairro  Quartos  Vagas  Suites  \
# 22     Casa de Condomínio           Barra da Tijuca        4      3       2
# 59     Casa de Condomínio           Barra da Tijuca        5     10       5
# 85     Casa de Condomínio   Freguesia (Jacarepaguá)        5      3       1
# 248    Casa de Condomínio           Barra da Tijuca        4      2       4
# 253    Casa de Condomínio  Recreio dos Bandeirantes        4      4       4
# ...                   ...                       ...      ...    ...     ...
# 32869  Casa de Condomínio           Barra da Tijuca        4      3       4
# 32898  Casa de Condomínio           Barra da Tijuca        5      2       5
# 32908  Casa de Condomínio   Freguesia (Jacarepaguá)        3      3       1
# 32924  Casa de Condomínio           Barra da Tijuca        3      5       3
# 32952  Casa de Condomínio           Barra da Tijuca        5      3       4
#
#        Area    Valor  Condominio    IPTU
# 22      466   7500.0      2695.0     NaN
# 59     1600  25000.0      1600.0     NaN
# 85      140   2500.0      1200.0     NaN
# 248     595  30000.0      2500.0  2510.0
# 253     267   6500.0       700.0  3308.0
# ...     ...      ...         ...     ...
# 32869   460  12000.0      1000.0  1200.0
# 32898   554  20000.0      1892.0  1743.0
# 32908   155   2000.0       530.0  1250.0
# 32924  1000  20000.0      3000.0     NaN
# 32952   450  15000.0      1711.0  2332.0
#
# [901 rows x 9 columns]

# %% [markdown]
# Selecionando todos os apartamentos com o valor de condominio nulo

# %%
select_apartamento = (dados['Tipo'] == 'Apartamento') & (dados['Condominio'].isnull())
dados[select_apartamento]
# Out:
#               Tipo           Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 5      Apartamento     Vista Alegre        3      1       0    70  1200.0
# 10     Apartamento           Centro        1      0       0    36  1200.0
# 113    Apartamento       Praça Seca        2      0       0    80  1000.0
# 166    Apartamento    Rocha Miranda        2      1       0    50  1100.0
# 194    Apartamento  Barra da Tijuca        1      1       1    65  2350.0
# ...            ...              ...      ...    ...     ...   ...     ...
# 32609  Apartamento       Copacabana        3      0       0   130  4600.0
# 32643  Apartamento        Guadalupe        1      0       0    40   550.0
# 32666  Apartamento       Bonsucesso        1      0       0    60  1000.0
# 32708  Apartamento         Flamengo        2      0       0    59  3500.0
# 32809  Apartamento        Cascadura        3      0       1    70  1200.0
#
#        Condominio  IPTU
# 5             NaN   NaN
# 10            NaN   NaN
# 113           NaN   NaN
# 166           NaN   NaN
# 194           NaN   NaN
# ...           ...   ...
# 32609         NaN   NaN
# 32643         NaN   NaN
# 32666         NaN   NaN
# 32708         NaN   NaN
# 32809         NaN   NaN
#
# [745 rows x 9 columns]

# %% [markdown]
# Descartando os apartamentos com o valor de condominio nulo

# %%
dados = dados[~select_apartamento]
dados
# Out:
#                           Tipo                Bairro  Quartos  Vagas  Suites  \
# 0                    Quitinete            Copacabana        1      0       0
# 1                         Casa       Jardim Botânico        2      0       1
# 2      Conjunto Comercial/Sala       Barra da Tijuca        0      4       0
# 3                  Apartamento                Centro        1      0       0
# 4                  Apartamento          Higienópolis        1      0       0
# ...                        ...                   ...      ...    ...     ...
# 32955                Quitinete                Centro        0      0       0
# 32956              Apartamento           Jacarepaguá        3      1       2
# 32957              Apartamento  São Francisco Xavier        2      1       0
# 32958              Apartamento                Leblon        2      0       0
# 32959  Conjunto Comercial/Sala                Centro        0      0       0
#
#        Area   Valor  Condominio    IPTU
# 0        40  1700.0       500.0    60.0
# 1       100  7000.0         NaN     NaN
# 2       150  5200.0      4020.0  1111.0
# 3        15   800.0       390.0    20.0
# 4        48   800.0       230.0     NaN
# ...     ...     ...         ...     ...
# 32955    27   800.0       350.0    25.0
# 32956    78  1800.0       800.0    40.0
# 32957    48  1400.0       509.0    37.0
# 32958    70  3000.0       760.0     NaN
# 32959   250  6500.0      4206.0  1109.0
#
# [32103 rows x 9 columns]

# %%
dados[dados["Condominio"].isnull()].shape[0]
# Out:
# 3249

# %% [markdown]
# Sobstituindo os valores faltantes (NaN) por 0

# %%
dados.fillna({'Condominio': 0, 'IPTU': 0}, inplace = True)
dados
# Out:
# <ipython-input-140-52f58cac74be>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dados.fillna({'Condominio': 0, 'IPTU': 0}, inplace = True)
#                           Tipo                Bairro  Quartos  Vagas  Suites  \
# 0                    Quitinete            Copacabana        1      0       0
# 1                         Casa       Jardim Botânico        2      0       1
# 2      Conjunto Comercial/Sala       Barra da Tijuca        0      4       0
# 3                  Apartamento                Centro        1      0       0
# 4                  Apartamento          Higienópolis        1      0       0
# ...                        ...                   ...      ...    ...     ...
# 32955                Quitinete                Centro        0      0       0
# 32956              Apartamento           Jacarepaguá        3      1       2
# 32957              Apartamento  São Francisco Xavier        2      1       0
# 32958              Apartamento                Leblon        2      0       0
# 32959  Conjunto Comercial/Sala                Centro        0      0       0
#
#        Area   Valor  Condominio    IPTU
# 0        40  1700.0       500.0    60.0
# 1       100  7000.0         0.0     0.0
# 2       150  5200.0      4020.0  1111.0
# 3        15   800.0       390.0    20.0
# 4        48   800.0       230.0     0.0
# ...     ...     ...         ...     ...
# 32955    27   800.0       350.0    25.0
# 32956    78  1800.0       800.0    40.0
# 32957    48  1400.0       509.0    37.0
# 32958    70  3000.0       760.0     0.0
# 32959   250  6500.0      4206.0  1109.0
#
# [32103 rows x 9 columns]

# %% [markdown]
# Verificando se os valores foram substituidos corretamente.

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32103 entries, 0 to 32959
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Tipo        32103 non-null  object
#  1   Bairro      32103 non-null  object
#  2   Quartos     32103 non-null  int64
#  3   Vagas       32103 non-null  int64
#  4   Suites      32103 non-null  int64
#  5   Area        32103 non-null  int64
#  6   Valor       32103 non-null  float64
#  7   Condominio  32103 non-null  float64
#  8   IPTU        32103 non-null  float64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 2.4+ MB

# %%
dados[dados["Condominio"].isnull()].shape[0]
# Out:
# 0

# %%
dados[dados["IPTU"].isnull()].shape[0]
# Out:
# 0

# %% [markdown]
# ### Adicionando novas colunas na base de dados

# %%
dados['Valor Bruto'] = dados['Valor'] + dados['Condominio'] + dados['IPTU']

dados
# Out:
# <ipython-input-144-a0cffdb307e0>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dados['Valor Bruto'] = dados['Valor'] + dados['Condominio'] + dados['IPTU']
#                           Tipo                Bairro  Quartos  Vagas  Suites  \
# 0                    Quitinete            Copacabana        1      0       0
# 1                         Casa       Jardim Botânico        2      0       1
# 2      Conjunto Comercial/Sala       Barra da Tijuca        0      4       0
# 3                  Apartamento                Centro        1      0       0
# 4                  Apartamento          Higienópolis        1      0       0
# ...                        ...                   ...      ...    ...     ...
# 32955                Quitinete                Centro        0      0       0
# 32956              Apartamento           Jacarepaguá        3      1       2
# 32957              Apartamento  São Francisco Xavier        2      1       0
# 32958              Apartamento                Leblon        2      0       0
# 32959  Conjunto Comercial/Sala                Centro        0      0       0
#
#        Area   Valor  Condominio    IPTU  Valor Bruto
# 0        40  1700.0       500.0    60.0       2260.0
# 1       100  7000.0         0.0     0.0       7000.0
# 2       150  5200.0      4020.0  1111.0      10331.0
# 3        15   800.0       390.0    20.0       1210.0
# 4        48   800.0       230.0     0.0       1030.0
# ...     ...     ...         ...     ...          ...
# 32955    27   800.0       350.0    25.0       1175.0
# 32956    78  1800.0       800.0    40.0       2640.0
# 32957    48  1400.0       509.0    37.0       1946.0
# 32958    70  3000.0       760.0     0.0       3760.0
# 32959   250  6500.0      4206.0  1109.0      11815.0
#
# [32103 rows x 10 columns]

# %%
dados['Valor m2'] = (dados['Valor']/dados['Area']).round(2)
dados
# Out:
# <ipython-input-145-9c10ec7a3417>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dados['Valor m2'] = (dados['Valor']/dados['Area']).round(2)
#                           Tipo                Bairro  Quartos  Vagas  Suites  \
# 0                    Quitinete            Copacabana        1      0       0
# 1                         Casa       Jardim Botânico        2      0       1
# 2      Conjunto Comercial/Sala       Barra da Tijuca        0      4       0
# 3                  Apartamento                Centro        1      0       0
# 4                  Apartamento          Higienópolis        1      0       0
# ...                        ...                   ...      ...    ...     ...
# 32955                Quitinete                Centro        0      0       0
# 32956              Apartamento           Jacarepaguá        3      1       2
# 32957              Apartamento  São Francisco Xavier        2      1       0
# 32958              Apartamento                Leblon        2      0       0
# 32959  Conjunto Comercial/Sala                Centro        0      0       0
#
#        Area   Valor  Condominio    IPTU  Valor Bruto  Valor m2
# 0        40  1700.0       500.0    60.0       2260.0     42.50
# 1       100  7000.0         0.0     0.0       7000.0     70.00
# 2       150  5200.0      4020.0  1111.0      10331.0     34.67
# 3        15   800.0       390.0    20.0       1210.0     53.33
# 4        48   800.0       230.0     0.0       1030.0     16.67
# ...     ...     ...         ...     ...          ...       ...
# 32955    27   800.0       350.0    25.0       1175.0     29.63
# 32956    78  1800.0       800.0    40.0       2640.0     23.08
# 32957    48  1400.0       509.0    37.0       1946.0     29.17
# 32958    70  3000.0       760.0     0.0       3760.0     42.86
# 32959   250  6500.0      4206.0  1109.0      11815.0     26.00
#
# [32103 rows x 11 columns]

# %%
dados['Valor Bruto m2'] = (dados['Valor Bruto']/dados['Area']).round(2)
dados
# Out:
# <ipython-input-146-74945e6ed75b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dados['Valor Bruto m2'] = (dados['Valor Bruto']/dados['Area']).round(2)
#                           Tipo                Bairro  Quartos  Vagas  Suites  \
# 0                    Quitinete            Copacabana        1      0       0
# 1                         Casa       Jardim Botânico        2      0       1
# 2      Conjunto Comercial/Sala       Barra da Tijuca        0      4       0
# 3                  Apartamento                Centro        1      0       0
# 4                  Apartamento          Higienópolis        1      0       0
# ...                        ...                   ...      ...    ...     ...
# 32955                Quitinete                Centro        0      0       0
# 32956              Apartamento           Jacarepaguá        3      1       2
# 32957              Apartamento  São Francisco Xavier        2      1       0
# 32958              Apartamento                Leblon        2      0       0
# 32959  Conjunto Comercial/Sala                Centro        0      0       0
#
#        Area   Valor  Condominio    IPTU  Valor Bruto  Valor m2  Valor Bruto m2
# 0        40  1700.0       500.0    60.0       2260.0     42.50           56.50
# 1       100  7000.0         0.0     0.0       7000.0     70.00           70.00
# 2       150  5200.0      4020.0  1111.0      10331.0     34.67           68.87
# 3        15   800.0       390.0    20.0       1210.0     53.33           80.67
# 4        48   800.0       230.0     0.0       1030.0     16.67           21.46
# ...     ...     ...         ...     ...          ...       ...             ...
# 32955    27   800.0       350.0    25.0       1175.0     29.63           43.52
# 32956    78  1800.0       800.0    40.0       2640.0     23.08           33.85
# 32957    48  1400.0       509.0    37.0       1946.0     29.17           40.54
# 32958    70  3000.0       760.0     0.0       3760.0     42.86           53.71
# 32959   250  6500.0      4206.0  1109.0      11815.0     26.00           47.26
#
# [32103 rows x 12 columns]

# %% [markdown]
# #Load

# %% [markdown]
# Exportando base de dados para um arquivo csv

# %%
dados.to_csv('aluguel_depois_tratamento.csv', sep = ';', index = False)
